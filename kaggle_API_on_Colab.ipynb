# %% [markdown]
# <a href="https://colab.research.google.com/github/wahid028/CryptoCurrency-Price-prediction_Kaggle/blob/main/kaggle_API_on_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#install kaggle
# !pip install -q kaggle

# %%
#upload the kaggle.json file
from google.colab import files
files.upload()

# %% [markdown]
# ### Upload kaggle.json file. To get this file follow the below steps
#
#
# 1.   go www.kaggle.com
# 2.   click on profile
# 3.   click on Account
# 4.   Under API section click on 'Create New API Token'
#
#
#
#
# ![kaggle.png](data:image/png;base64,...)

# %%
#create a kaggle directory
# !mkdir ~/.kaggledataset

# %%
#copy the kaggle.json to kaggle directory
# !cp kaggle.json ~/.kaggledataset/

# %%
#permission for the json to act
# !chmod 600 ~/.kaggledataset/kaggle.json

# %%
#list all the available dataset in kaggle
# !kaggle datasets list
# !kaggle competitions download -c g-research-crypto-forecasting [write your required dataset name]
